# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### IMPORTING / VIEWING / PREPROCESSING DATASET

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [00:15<00:00,  3.12s/it]

# %% [markdown]
# ### MODEL BUILDING

# %%
base_model = VGG16(input_shape=(224,224,3), 
                   include_top=False,
                   weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25088)             100352
# _________________________________________________________________
# dense (Dense)                (None, 2048)              51382272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 68,311,876
# Trainable params: 53,540,868
# Non-trainable params: 14,771,008
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)
METRIC = tensorflow.keras.metrics.AUC(name = 'auc')

model.compile(loss='categorical_crossentropy',
              metrics=METRIC,
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = './weights.h5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 25,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/25
# 33/33 [==============================] - ETA: 0s - loss: 1.3919 - auc: 0.7729
# Epoch 00001: val_auc improved from -inf to 0.71089, saving model to ./weights.h5
# 33/33 [==============================] - 69s 2s/step - loss: 1.3919 - auc: 0.7729 - val_loss: 1.3783 - val_auc: 0.7109
# Epoch 2/25
# 33/33 [==============================] - ETA: 0s - loss: 1.1596 - auc: 0.8131
# Epoch 00002: val_auc improved from 0.71089 to 0.76050, saving model to ./weights.h5
# 33/33 [==============================] - 54s 2s/step - loss: 1.1596 - auc: 0.8131 - val_loss: 1.1426 - val_auc: 0.7605
# Epoch 3/25
# 33/33 [==============================] - ETA: 0s - loss: 1.0682 - auc: 0.8282
# Epoch 00003: val_auc did not improve from 0.76050
# 33/33 [==============================] - 52s 2s/step - loss: 1.0682 - auc: 0.8282 - val_loss: 1.1702 - val_auc: 0.7290
# Epoch 4/25
# 33/33 [==============================] - ETA: 0s - loss: 0.9965 - auc: 0.8416
# Epoch 00004: val_auc improved from 0.76050 to 0.76556, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.9965 - auc: 0.8416 - val_loss: 1.1022 - val_auc: 0.7656
# Epoch 5/25
# 33/33 [==============================] - ETA: 0s - loss: 0.9481 - auc: 0.8534
# Epoch 00005: val_auc improved from 0.76556 to 0.79505, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.9481 - auc: 0.8534 - val_loss: 1.0346 - val_auc: 0.7950
# Epoch 6/25
# 33/33 [==============================] - ETA: 0s - loss: 0.9298 - auc: 0.8564
# Epoch 00006: val_auc improved from 0.79505 to 0.81643, saving model to ./weights.h5
# 33/33 [==============================] - 54s 2s/step - loss: 0.9298 - auc: 0.8564 - val_loss: 1.0153 - val_auc: 0.8164
# Epoch 7/25
# 33/33 [==============================] - ETA: 0s - loss: 0.8961 - auc: 0.8639
# Epoch 00007: val_auc did not improve from 0.81643
# 33/33 [==============================] - 51s 2s/step - loss: 0.8961 - auc: 0.8639 - val_loss: 1.0484 - val_auc: 0.8066
# Epoch 8/25
# 33/33 [==============================] - ETA: 0s - loss: 0.8744 - auc: 0.8689
# Epoch 00008: val_auc did not improve from 0.81643
# 33/33 [==============================] - 51s 2s/step - loss: 0.8744 - auc: 0.8689 - val_loss: 1.0575 - val_auc: 0.7885
# Epoch 9/25
# 33/33 [==============================] - ETA: 0s - loss: 0.8519 - auc: 0.8726
# Epoch 00009: val_auc did not improve from 0.81643
# 33/33 [==============================] - 52s 2s/step - loss: 0.8519 - auc: 0.8726 - val_loss: 1.0010 - val_auc: 0.8086
# Epoch 10/25
# 33/33 [==============================] - ETA: 0s - loss: 0.8229 - auc: 0.8794
# Epoch 00010: val_auc improved from 0.81643 to 0.81692, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.8229 - auc: 0.8794 - val_loss: 0.9806 - val_auc: 0.8169
# Epoch 11/25
# 33/33 [==============================] - ETA: 0s - loss: 0.8074 - auc: 0.8833
# Epoch 00011: val_auc did not improve from 0.81692
# 33/33 [==============================] - 51s 2s/step - loss: 0.8074 - auc: 0.8833 - val_loss: 1.0061 - val_auc: 0.8127
# Epoch 12/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7941 - auc: 0.8872
# Epoch 00012: val_auc did not improve from 0.81692
# 33/33 [==============================] - 51s 2s/step - loss: 0.7941 - auc: 0.8872 - val_loss: 1.0403 - val_auc: 0.8025
# Epoch 13/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7779 - auc: 0.8909
# Epoch 00013: val_auc improved from 0.81692 to 0.82750, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.7779 - auc: 0.8909 - val_loss: 0.9747 - val_auc: 0.8275
# Epoch 14/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7846 - auc: 0.8894
# Epoch 00014: val_auc did not improve from 0.82750
# 33/33 [==============================] - 51s 2s/step - loss: 0.7846 - auc: 0.8894 - val_loss: 1.0283 - val_auc: 0.8253
# Epoch 15/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7710 - auc: 0.8928
# Epoch 00015: val_auc did not improve from 0.82750
# 33/33 [==============================] - 51s 2s/step - loss: 0.7710 - auc: 0.8928 - val_loss: 0.9918 - val_auc: 0.8232
# Epoch 16/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7601 - auc: 0.8958
# Epoch 00016: val_auc did not improve from 0.82750
# 33/33 [==============================] - 51s 2s/step - loss: 0.7601 - auc: 0.8958 - val_loss: 1.0670 - val_auc: 0.8084
# Epoch 17/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7539 - auc: 0.8959
# Epoch 00017: val_auc did not improve from 0.82750
# 33/33 [==============================] - 51s 2s/step - loss: 0.7539 - auc: 0.8959 - val_loss: 1.0645 - val_auc: 0.8041
# Epoch 18/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7430 - auc: 0.8994
# Epoch 00018: val_auc did not improve from 0.82750
# 33/33 [==============================] - 52s 2s/step - loss: 0.7430 - auc: 0.8994 - val_loss: 1.0738 - val_auc: 0.8242
# Epoch 19/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7160 - auc: 0.9060
# Epoch 00019: val_auc improved from 0.82750 to 0.82895, saving model to ./weights.h5
# 33/33 [==============================] - 54s 2s/step - loss: 0.7160 - auc: 0.9060 - val_loss: 1.0047 - val_auc: 0.8289
# Epoch 20/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7155 - auc: 0.9061
# Epoch 00020: val_auc did not improve from 0.82895
# 33/33 [==============================] - 51s 2s/step - loss: 0.7155 - auc: 0.9061 - val_loss: 1.0263 - val_auc: 0.8212
# Epoch 21/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7170 - auc: 0.9065
# Epoch 00021: val_auc improved from 0.82895 to 0.83127, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.7170 - auc: 0.9065 - val_loss: 1.0996 - val_auc: 0.8313
# Epoch 22/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7355 - auc: 0.9016
# Epoch 00022: val_auc did not improve from 0.83127
# 33/33 [==============================] - 52s 2s/step - loss: 0.7355 - auc: 0.9016 - val_loss: 1.0909 - val_auc: 0.8186
# Epoch 23/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7074 - auc: 0.9090
# Epoch 00023: val_auc did not improve from 0.83127
# 33/33 [==============================] - 53s 2s/step - loss: 0.7074 - auc: 0.9090 - val_loss: 1.0213 - val_auc: 0.8242
# Epoch 24/25
# 33/33 [==============================] - ETA: 0s - loss: 0.6901 - auc: 0.9130
# Epoch 00024: val_auc improved from 0.83127 to 0.84001, saving model to ./weights.h5
# 33/33 [==============================] - 53s 2s/step - loss: 0.6901 - auc: 0.9130 - val_loss: 0.9863 - val_auc: 0.8400
# Epoch 25/25
# 33/33 [==============================] - ETA: 0s - loss: 0.7170 - auc: 0.9059
# Epoch 00025: val_auc did not improve from 0.84001
# 33/33 [==============================] - 51s 2s/step - loss: 0.7170 - auc: 0.9059 - val_loss: 1.0767 - val_auc: 0.8272

# %%
model.save('vgg16.h5')

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
import numpy as np

# %%
y=np.concatenate([valid_dataset.next()[1] for i in range(valid_dataset.__len__())])
true_labels=np.argmax(y, axis=-1)
prediction= model.predict(valid_dataset, verbose=2)
prediction=np.argmax(prediction, axis=-1)
# Out:
# 8/8 - 2s

# %%
import matplotlib.pyplot as plt

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=85)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
cm = confusion_matrix(y_true=true_labels, y_pred=prediction)

# %%
cm_plot_labels = ["MildDemented","ModerateDemented","NonDemented","VeryMildDemented"]

# %%
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
from sklearn.metrics import accuracy_score
acc=accuracy_score(true_labels,prediction) 
print('Accuracy: %.3f' % acc)
from sklearn.metrics import precision_score
precision = precision_score(true_labels,prediction,labels=[1,2], average='micro')
print('Precision: %.3f' % precision)
from sklearn.metrics import recall_score
recall = recall_score(true_labels,prediction, average='micro')
print('Recall: %.3f' % recall)
from sklearn.metrics import f1_score
score = f1_score(true_labels,prediction, average='micro')
print('F-Measure: %.3f' % score)
# Out:
# Confusion matrix, without normalization
# [[ 59   1  57  26]
#  [  0   7   3   0]
#  [ 56   0 397  59]
#  [ 49   3 220  86]]
# Accuracy: 0.537
# Precision: 0.587
# Recall: 0.537
# F-Measure: 0.537

# %%
ji
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-29c9770ea58a> in <module>
# ----> 1 ji
#
# NameError: name 'ji' is not defined
